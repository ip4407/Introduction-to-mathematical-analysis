# %% [markdown]
# # Урок 2

# %% [markdown]
# # Теория множеств. Математическая логика.

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# ---
# ### **Задание 1.**
# #### Представьте в виде **несократимой** рациональной дроби:

# %% [markdown]
# ### $а)\,\,\, 0.(216);$
# #### $$b=0.(216)$$
# #### $$1000b=216.(216)$$
# #### $$1000b=216+0.(216)$$
# #### $$1000b=216+b$$
# #### $$999b=216$$
# #### $$b=\frac{216}{999}=\frac{24}{111}$$
# #### $$0.(216)=\frac{24}{111}$$

# %%
24/111
# Out:
# 0.21621621621621623

# %% [markdown]
# ### $б)\,\,\, 1.0(01).$
#
# #### $$b=1.0(01)$$
# #### $$10b=10.(01)$$
# #### $$10b=10+0.(01)$$
# #### $$100*0.(01)=1.(01)$$
# #### $$100*0.(01)=1+0.(01)$$
# #### $$99*0.(01)=1$$
# #### $$0.(01)=\frac{1}{99}$$
# #### $$10b=10+\frac{1}{99}$$
# #### $$10b=\frac{10*99}{99}+\frac{1}{99}=\frac{991}{99}$$
# #### $$b=\frac{991}{990}$$
# #### $$1.0(01)=\frac{991}{990}$$

# %%
991/990
# Out:
# 1.001010101010101

# %% [markdown]
# ---

# %% [markdown]
# ---
# ### Задание 3.
# #### Проверьте любым способ, является ли данные логические формулы тавтологией:

# %% [markdown]
# $a)\,\,\, (A \vee B) \rightarrow (B \vee\overline A)$
#
# Решим с помощью таблицы истинности:
#
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$A\vee B$</th><th>$\overline A$</th><th>$B\vee \overline A$</th><th>$(A \vee B) \rightarrow (B\vee \overline A)$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$0$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
#
# **ОТВЕТ:** Так как выражение **не** принимает истинное значение при любых значениях входящих в нее простых высказываний, то такое выражение **не является тавтологией**.

# %% [markdown]
# $б)\,\,\, A \rightarrow (A \vee (\overline B \wedge A))$
#
# Решим с помощью таблицы истинности:
#
# <table>
# <thead>
# <tr><th>$A$</th><th>$B$</th><th>$\overline B$</th><th>$\overline B\wedge A$</th><th>$A\vee(\overline B\wedge A)$</th><th>$A\rightarrow(A \vee(\overline B\wedge A))$</th></tr>
# </thead>
# <tbody>
#     <tr><td>$0$</td><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$0$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$0$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$0$</td><td>$1$</td><td>$1$</td><td>$1$</td><td>$1$</td></tr>
#     <tr><td>$1$</td><td>$1$</td><td>$0$</td><td>$0$</td><td>$1$</td><td>$1$</td></tr>
# </tbody>
# </table>
#
# **ОТВЕТ:** Так как выражение принимает истинное значение при любых значениях входящих в нее простых высказываний, то такое выражение **является тавтологией**.
#
# ---

# %% [markdown]
# ---
# ### Задание 4.
# #### Сформулируйте словесно высказывания:

# %% [markdown]
# $a)\,\,\, (\overline A \vee B) \rightarrow \overline C$
# - $A:\,\,\,$ сегодня светит солнце;
# - $B:\,\,\,$ сегодня сыро;
# - $C:\,\,\,$ я поеду на дачу.
#
# **ОТВЕТ:** _"Если сегодня не светит солнце или сегодня сыро, то я не поеду на дачу"._

# %% [markdown]
# $б)\,\,\, C \rightarrow (A \vee \overline B)$
# - $A:\,\,\,$ сегодня светит солнце;
# - $B:\,\,\,$ сегодня сыро;
# - $C:\,\,\,$ я поеду на дачу.
#
# **ОТВЕТ:** _"Если я поеду на дачу, то сегодня светит солнце или сегодня не сыро"._
#
# ---

# %% [markdown]
# ---
# ### Задание 5.
# #### Пользуясь правилом построения противоположного высказывания, запишите утверждения, противоположные следующим:
#
# ##### a) На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».
#
# $$\forall \,\,\, курсе \,\,\, \forall \,\,\,факультета \,\,\, \exists \,\,\, студенты,\,\,\, сдающие \,\,\, \forall \,\,\, экзамены\,\,\, на\,\,\, «отлично».$$
# $$\exists \,\,\, курсе \,\,\, \exists \,\,\,факультета \,\,\, \forall \,\,\, студенты,\,\,\, сдающие \,\,\, \exists \,\,\, экзамены\,\,\, на\,\,\, «неудовлетворительно».$$
#
# **ОТВЕТ:** _"Есть курс факультета, где все студенты сдают экзамен на "неудовлетворительно"._
#
# ##### б) В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой пуговице одежды которого вмонтирован микрофон.
#
# $$\forall \,\,\, самолете\,\,\, на\,\,\, рейсе\,\,\, Вашингтон-Москва \,\,\,  \exists \,\,\,хотя\,\,\, бы\,\,\, один\,\,\, сотрудник\,\,\, силовых\,\,\, органов,\,\,\, в \,\,\, \forall \,\,\, пуговице\,\,\, одежды\,\,\, которого\,\,\,$$
# $$вмонтирован\,\,\, микрофон.$$
# $$\exists \,\,\, самолете\,\,\, на\,\,\, рейсе\,\,\, Вашингтон-Москва \,\,\,  \forall \,\,\,хотя\,\,\, бы\,\,\, один\,\,\, сотрудник\,\,\, силовых\,\,\, органов,\,\,\, в \,\,\, \exists \,\,\, пуговице\,\,\, одежды\,\,\, которого\,\,\,$$
# $$не\,\,\, вмонтирован\,\,\, микрофон.$$
#
# **ОТВЕТ:** _"Существует самолет на рейсе Вашингтон-Москва, где все сотрудники силовых органов, в пуговице одежды которых не вмонтирован микрофон"._
#
# ---
